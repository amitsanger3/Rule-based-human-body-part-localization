# %%
# ! pip install opencv-python==4.6.0.66
# ! pip install torch
# ! pip install matplotlib
# ! pip install tqdm

# https://github.com/timesler/facenet-pytorch

# %%
import cv2

import numpy as np
import matplotlib.pyplot as plt

import os, json
import random, traceback

import time
from tqdm import tqdm

import shutil

import torch
from torch import nn
import torch.nn.functional as F
# from sklearn.model_selection import train_test_split

# %matplotlib inline

# %%
Vogue_path = r"F:\Documents\PROJECT\ANALYSIS\twitter\VOGUE"
os.listdir(Vogue_path)
# Out:
# ['1205',
#  '16Arlington',
#  '1_Piu_1_Uguale_3',
#  '3x1',
#  '3_1_Phillip_Lim',
#  '4SDesigns',
#  '5_Knot',
#  '6267',
#  '6397',
#  '87MM',
#  '99_IS_',
#  'Aalto',
#  'Abaeté',
#  'Abasi_Rosborough',
#  'Academy_of_Art_University',
#  'Ace___Jig',
#  'Acler',
#  'Acne_Studios',
#  'Adam_Kimmel',
#  'Adam_Lippes',
#  'Adam_Selman',
#  'Adam_Selman_Sport',
#  'Adeam',
#  'Adidas_by_Stella_McCartney',
#  'Adriana_Degreas',
#  'AG',
#  'Aganovich',
#  'Agi___Sam',
#  'AGL',
#  'Agnona',
#  'Agnès_B_',
#  'Ahluwalia',
#  'Ailanto',
#  'Aje',
#  'Aka_Nanita',
#  'Akikoaoki',
#  'Akira',
#  'Akris',
#  'Alabama_Chanin',
#  'Alaïa',
#  'Albagìa',
#  'Alberta_Ferretti',
#  'Alberta_Ferretti_Limited_Edition',
#  'Albino_Teodoro',
#  'Albus_Lumen',
#  'Alchemist',
#  'Alejandra_Alonso_Rojas',
#  'Alena_Akhmadullina',
#  'Alessandra_Rich',
#  'Alessandro_Dell_Acqua',
#  'ALEXACHUNG',
#  'Alexander_Arutyunov',
#  'Alexander_Lewis',
#  'Alexander_McQueen',
#  'Alexander_Wang',
#  'Alexandre_Herchcovitch',
#  'Alexandre_Matthieu',
#  'Alexandre_Plokhov',
#  'Alexandre_Vauthier',
#  'Alexis_Mabille',
#  'Alex_Perry',
#  'Alfredo_Martínez',
#  'Alice_Auaa',
#  'Alice_McCall',
#  'Alice_Roi',
#  'Alice___Olivia',
#  'Alina_Zamanova',
#  'Alisa_Kuzembaeva',
#  'Alistair_Carr',
#  'Alix_Higgins',
#  'Aliétte',
#  'Allegra_Hicks',
#  'All_In',
#  'Alonova',
#  'AltewaiSaome',
#  'Altuzarra',
#  'Alyx',
#  'Ambush',
#  'Ami',
#  'Amiri',
#  'Amsale',
#  'Anaïs_Jourden',
#  'Andreadamo',
#  'Andreas_Kronthaler_for_Vivienne_Westwood',
#  'Andrea_Pompilio',
#  'Andreeva',
#  'Andrew_Gn',
#  'Andy___Debb',
#  'And_Re_Walker',
#  'And_Wander',
#  'Angelos_Bratis',
#  'Angel_Chen',
#  'Angel_Sanchez',
#  'Animale',
#  'Anja_Gockel',
#  'Annakiki',
#  'Anna_K',
#  'Anna_Molinari',
#  'Anna_October',
#  'Anna_Sui',
#  'Anne_Barge',
#  'Anne_Klein',
#  'Anne_Sofie_Madsen',
#  'Anne_Valérie_Hash',
#  'Ann_Demeulemeester',
#  'Ann_Sofie_Back_Atelje',
#  'Anonlychild',
#  'Anouki',
#  'Anrealage',
#  'Anteprima',
#  'Anthony_Vaccarello',
#  'Antonio_Azzuolo',
#  'Antonio_Berardi',
#  'Antonio_Croce',
#  'Antonio_Grimaldi',
#  'Antonio_Marras',
#  'Anton_Belinskiy',
#  'Anya_Hindmarch',
#  'An_American_View',
#  'Aouadi',
#  'Apartamento_03',
#  'Apiece_Apart',
#  'Aquascutum',
#  'Aquilano_Rimondi',
#  'Araisara',
#  'Araks',
#  'Area',
#  'Ariunaa_Suri',
#  'Arjé',
#  'Arkadius',
#  'Armand_Basi_One',
#  'Armani_Privé',
#  'Armarium',
#  'Artemklimchuk',
#  'Artem_Shumov',
#  'Arthur_Arbesser',
#  'Art_School',
#  'ASAI',
#  'Asger_Juel_Larsen',
#  'Ashish',
#  'Ashi_Studio',
#  'Ashley_Williams',
#  'Ashlyn',
#  'Asian_Fashion_Meets_Tokyo',
#  'Astrid_Andersen',
#  'As_Four',
#  'Atelier_Kikala',
#  'Atelier_Versace',
#  'Atlein',
#  'ATM_Anthony_Thomas_Melillo',
#  'Ato',
#  'Atsushi_Nakashima',
#  'Atto',
#  'ATXV',
#  'Audra',
#  'Augustin_Teboul',
#  'Aula',
#  'Autumn_Adeigbo',
#  'Au_Jour_Le_Jour',
#  'Avalone',
#  'Avavav',
#  'Avtandil',
#  'Awaveawake',
#  'Azzaro',
#  'AZ_Factory',
#  'A_A__Antonio_Azzuolo',
#  'A_Cold_Wall',
#  'A_Degree_Fahrenheit',
#  'A_Détacher',
#  'A_F__Vandevorst',
#  'A_L_C_',
#  'A_M_G_',
#  'A_Peace_Treaty',
#  'A_P_C_',
#  'A_W_A_K_E__MODE',
#  'A__Company',
#  'A__Potts',
#  'A__Roege_Hove',
#  'A__Sauvage',
#  'A__Teodoro',
#  'Babyghost',
#  'Bach_Mai',
#  'Badgley_Mischka',
#  'Baja_East',
#  'Baldessarini',
#  'Balenciaga',
#  'Bally',
#  'Balmain',
#  'Banana_Republic',
#  'Bande_Noir',
#  'Band_of_Outsiders',
#  'Barbara_Bui',
#  'Barbara_Casasola',
#  'Barbara_Tfank',
#  'Barbara_í_Gongini',
#  'Barragán',
#  'Barre_Noire',
#  'Base_Mark',
#  'Bassike',
#  'Basso___Brooke',
#  'Batsheva',
#  'Baum_und_Pferdgarten',
#  'BCBG_Max_Azria',
#  'Beatrice__b',
#  'Beaufille',
#  'Beautiful_People',
#  'Bebe',
#  'Beckmans_College_of_Design',
#  'Bed_j_w__Ford',
#  'Behnaz_Sarafpour',
#  'Bekh',
#  'Believe_in_Better',
#  'Bella_Freud',
#  'Belstaff',
#  'Benjamin_Cho',
#  'Bensoni',
#  'Berardi',
#  'Berluti',
#  'Berner_Kühl',
#  'Bernhard_Willhelm',
#  'Be_Blumarine',
#  'Bode',
#  'Boglioli',
#  'Boramy_Viguier',
#  'Bora_Aksu',
#  'Boris_Bidjan_Saberi',
#  'Boss',
#  'Bottega_Veneta',
#  'Botter',
#  'Bouchra_Jarrar',
#  'Brood',
#  'Brooks_Brothers',
#  'Bruce',
#  'Brunello_Cucinelli',
#  'Bruno_Pieters',
#  'Bruuns_Bazaar',
#  'Buckler',
#  'Buddhist_Punk',
#  'Burberry',
#  'Byblos',
#  'By_Johnny',
#  'By_Malene_Birger',
#  'BY__Bonnie_Young',
#  'B__Umit_Benan',
#  'Bárbara_Sánchez_Kane',
#  'Cacharel',
#  'Cadet',
#  'Calla',
#  'Callaghan',
#  'CALVIN_KLEIN_205W39NYC',
#  'Calvin_Klein_Collection',
#  'Calvin_Luo',
#  'Camilla_and_Marc',
#  'Canali',
#  'Capasa_Milano',
#  'Capucci',
#  'Carin_Wester',
#  'Carla_Zampatti',
#  'Carlos_Miele',
#  'Carlo_Ponti',
#  'Carmen_March',
#  'Carmen_Marc_Valvo',
#  'Carolina_Herrera',
#  'Carven',
#  'Casablanca',
#  'Celine',
#  'Central_Saint_Martins',
#  'Cerre',
#  'Cerruti',
#  'Cerruti_1881',
#  'CFCL',
#  'CF_Goldman',
#  'CG',
#  'Chadwick_Bell',
#  'Chaiken',
#  'Chakshyn',
#  'Chalayan',
#  'Chanel',
#  'Charles_Anastase',
#  'Charles_de_Vilmorin',
#  'Charles_Jeffrey_Loverboy',
#  'Charles_Nolan',
#  'Charlotte_Olympia',
#  'Charlotte_Ronson',
#  'Charm’s',
#  'Cheap_Monday',
#  'Cher_Michel_Klein',
#  'Chet_Lo',
#  'Chiara_Ferragni',
#  'Chika_Kisada',
#  'Children_of_the_Discordance',
#  'Childs',
#  'Chloé',
#  'Chloë_Sevigny_for_O_C_',
#  'Chocheng',
#  'Chono',
#  'Chopova_Lowena',
#  'Christian_Cota',
#  'Christian_Cowan',
#  'Christian_Dada',
#  'Christian_Dior',
#  'Christian_Francis_Roth',
#  'Christian_Lacroix',
#  'Christian_Siriano',
#  'Christian_Wijnants',
#  'Christopher_Esber',
#  'Christopher_John_Rogers',
#  'Christopher_Kane',
#  'Christopher_Shannon',
#  'Chris_Benz',
#  'Chromat',
#  'Chufy',
#  'Cienne',
#  'Cihan_Nacar',
#  'Cinoh',
#  'Cinq_à_Sept',
#  'Cividini',
#  'Claudia_Li',
#  'Clements_Ribeiro',
#  'Cloak',
#  'Clover_Canyon',
#  'Club_Monaco',
#  'CMMN_SWDN',
#  'Co',
#  'Coach',
#  'Colcci',
#  'Collette_Dinnigan',
#  'Collina_Strada',
#  'Colovos',
#  'Colville',
#  'Comme_des_Garçons',
#  'Comme_des_Garçons_Comme_des_Garçons',
#  'Comme_des_Garçons_Homme_Plus',
#  'Comme_des_Garçons_Shirt',
#  'Commission',
#  'Commonwealth_Utilities',
#  'Commuun',
#  'Comptoir_des_Cotonniers',
#  'Cong_Tri',
#  'Conner_Ives',
#  'Connor_McKnight',
#  'Conny_Groenewegen',
#  'Coperni',
#  'Cormio',
#  'Corneliani',
#  'COS',
#  'Costello_Tagliapietra',
#  'Costume_National',
#  'Cotoo',
#  'Cottweiler',
#  'Courrèges',
#  'Coven',
#  'Craig_Green',
#  'Creative_Taiwan',
#  'Creatures_of_Comfort',
#  'Creatures_of_the_Wind',
#  'Cres__E_Dim_',
#  'Crippen',
#  'Cult_Gaia',
#  'Curated_by_Ek_Thongprasert',
#  'Cushnie',
#  'Cushnie_et_Ochs',
#  'Custo_Barcelona',
#  'Cut25_by_Yigal_Azrouël',
#  'Cynthia_Rowley',
#  'Cynthia_Steffe',
#  'C_Neeon',
#  'C_P__Company',
#  'Câllas_Milano',
#  'Daalarna_Couture',
#  'Dailyroutine',
#  'Daks',
#  'Daks_by_Giles_Deacon',
#  'Dalood',
#  'Damir_Doma',
#  'Danielle_Frankel',
#  'Danielle_Scutt',
#  'Daniel_Vosovic',
#  'Daniel_W__Fletcher',
#  'Daryl_K',
#  'Dasha_Gauser',
#  'Datuna',
#  'Datuna_Sulikashvili',
#  'Daughters',
#  'Davidelfin',
#  'David_Catalan',
#  'David_Hart',
#  'David_Koma',
#  'David_Michael',
#  'Dax_Gabler',
#  'DAY_Birger_et_Mikkelsen',
#  'Dean_Quinn',
#  'Death_To_Tennis',
#  'Deceive',
#  'Delpozo',
#  'Del_Core',
#  'Dennis_Basso',
#  'Denzil_Patrick',
#  'Derek_Lam',
#  'Derek_Lam_10_Crosby',
#  'Derercuny',
#  'Designers_Remix',
#  'Deveaux',
#  'Devi_Kroell',
#  'Devon_Halfnight_LeFlufy',
#  'Diana_Orving',
#  'Diane_von_Furstenberg',
#  'Dice_Kayek',
#  'Diesel',
#  'Diesel_Black_Gold',
#  'Dietrich_Emter',
#  'Dilara_Findikoglu',
#  'Dimaneu',
#  'Dimitri',
#  'Dion_Lee',
#  'Dior_Men',
#  'Diotima',
#  'Dirk_Bikkembergs',
#  'Dirk_Schönberger',
#  'Discount_Universe',
#  'Discovered',
#  'Di_Petsa',
#  'Djaba_Diassamidze',
#  'DKNY',
#  'DMDV',
#  'Dolce___Gabbana',
#  'Domanoff',
#  'Dondup',
#  'Donna_Karan',
#  'Doo_Ri',
#  'Dorothee_Schumacher',
#  'Doublet',
#  'Double_Rainbouu',
#  'Douglas_Hannant',
#  'Drag___Drop',
#  'DressCamp',
#  'DressedUndressed',
#  'Dries_Van_Noten',
#  'Dsquared2',
#  'Duckie_Brown',
#  'Duncan',
#  'Dundas',
#  'Dunhill',
#  'Duran_Lantink',
#  'Duro_Olowu',
#  'Dyn',
#  'Dyne',
#  'Dzhus',
#  'D_G',
#  'D_Gnak',
#  'Each_x_Other',
#  'Eckhaus_Latta',
#  'Edeline_Lee',
#  'Edun',
#  'Edward_Crutchley',
#  'Eftychia',
#  'Egonlab',
#  'Electric_Feathers',
#  'Elenareva',
#  'Elena_Burba',
#  'Elena_Burenina',
#  'Elena_Rial',
#  'Elena_Velez',
#  'Eleykishimoto_Ellesse',
#  'Eley_Kishimoto',
#  'Elie_Saab',
#  'Elie_Tahari',
#  'Elise_Øverland',
#  'Elizabeth_and_James',
#  'Elizabeth_Kennedy',
#  'Ellen_Tracy',
#  'Ellery',
#  'Eloshi',
#  'Elspeth_Gibson',
#  'Emanuel_Ungaro',
#  'Emelie_Janrell',
#  'Emilia_Wickstead',
#  'Emilio_de_la_Morena',
#  'Emilio_Pucci',
#  'Emma_Cook',
#  'Emma_Mulholland',
#  'Emporio_Armani',
#  'Emre_Erdemoğlu',
#  'Enfants_Riches_Déprimés',
#  'Engineered_Garments',
#  'Erdem',
#  'Eric_Bergère',
#  'Eric_Schlösberg',
#  'Erika_Cavallini',
#  'Erin_Fetherston',
#  'Erin_Wasson_x_RVCA',
#  'ERL',
#  'Ermanno_Scervino',
#  'Ernesto_Naranjo',
#  'Ernest_W__Baker',
#  'Escada',
#  'Esse',
#  'Esteban_Cortazar',
#  'Ester_Manas',
#  'Esther_Perbandt',
#  'Ethosens',
#  'Etro',
#  'Etw_Vonneguet',
#  'Et_Momonakia',
#  'Et_Ochs',
#  'Eudon_Choi',
#  'European_Culture',
#  'Everlasting_Sprout',
#  'Eytys',
#  'E__Tautz',
#  'Fabiana_Filippi',
#  'Facetasm',
#  'Factotum',
#  'Faith_Connexion',
#  'Farah_Angsana',
#  'Fashion_East',
#  'Fashion_Fringe',
#  'Fassbender',
#  'Faustine_Steinmetz',
#  'Fausto_Puglisi',
#  'Fay',
#  'Fear_of_God',
#  'Feben',
#  'Felder_Felder',
#  'Felipe_Oliveira_Baptista',
#  'Fendi',
#  'Fendi_by_Versace',
#  'Feng_Chen_Wang',
#  'Fenty_x_Puma',
#  'Ferragamo',
#  'Ferrari',
#  'Fetico',
#  'Fe_Noel',
#  'Fforme',
#  'FILA',
#  'Filippa_K',
#  'Filippa_K_Man',
#  'Filles_à_Papa',
#  'Flannel',
#  'Fleamadonna',
#  'Florentina_Leitner',
#  'Flow_the_Label',
#  'Fonnesbech',
#  'For_Restless_Sleepers',
#  'Frame',
#  'Francesco_Scognamiglio',
#  'Francesc_by_Frank_Tell',
#  'Francisco_Cancino',
#  'Frank_Tell',
#  'Françoise',
#  'Frederick_Anderson',
#  'Freiknock',
#  'Freya_Dalsjø',
#  'Frolov',
#  'FrostFrench',
#  'Fumito_Ganryu',
#  'Fur_Fur',
#  'Féraud',
#  'Gabriela_Hearst',
#  'Gabriele_Colangelo',
#  'Gabrielle_Greiss',
#  'Gail_Sorronda',
#  'Galia_Lahav',
#  'Galvan',
#  'Ganni',
#  'Ganryu',
#  'Gant_by_Michael_Bastian',
#  'Gap',
#  'Gardem',
#  'Gareth_Pugh',
#  'Gary_Graham',
#  'Gasanova',
#  'Gauchere',
#  'GCDS',
#  'Generra',
#  'Genny',
#  'George_Amirejibi',
#  'George_Keburia',
#  'George_Pantsulaia',
#  'Giada',
#  'Giambattista_Valli',
#  'Giamba_by_Giambattista_Valli',
#  'Gianfranco_Ferré',
#  'Gibo',
#  'Gibsh',
#  'Gieves___Hawkes',
#  'Gilded_Age',
#  'Giles_Deacon',
#  'Ginger___Smart',
#  'Giorgio_Armani',
#  'Giuliana_Romanno',
#  'Giulietta',
#  'Givenchy',
#  'Gloria_Coelho',
#  'GmbH',
#  'Goga_Nikabadze',
#  'Gola_Damian',
#  'Gosha_Rubchinskiy',
#  'Graeme_Armour',
#  'Graeme_Black',
#  'Greedilous_by_Tilda',
#  'Gregory_Parkinson',
#  'Greg_Lauren',
#  'Greta_Constantine',
#  'Greta_Gram',
#  'Growing_Pains',
#  'Gryphon',
#  'Gucci',
#  'Gudu',
#  'Guo_Pei',
#  'Gustav_Von_Aschenbach',
#  'Gut_s_Dynamite_Cabarets',
#  'Gypsy_Sport',
#  'G_Star',
#  'G_V_G_V_',
#  'Gülçin_Çengel',
#  'Habitual',
#  'Haider_Ackermann',
#  'Hakaan',
#  'Hakaan_Yıldırım',
#  'Halpern',
#  'Halston',
#  'Halston_Heritage',
#  'Hamish_Morrow',
#  'HAN',
#  'Hanae_Mori_Manuscrit',
#  'Haney',
#  'Hanifa',
#  'Hanii_Y',
#  'Hannah_Marshall',
#  'Han_Ahn_Soon',
#  'Han_Kjøbenhavn',
#  'Hardware_LDN',
#  'Hardy_Amies',
#  'HARE',
#  'Harmon',
#  'Harris_Reed',
#  'Haryono_Setiadi',
#  'Hatice_Gökçe',
#  'Haus_Alkire',
#  'Head_of_State',
#  'Heatherette',
#  'Hecho',
#  'Hed_Mayner',
#  'Heich_Es_Heich',
#  'Helbers',
#  'Heliot_Emil',
#  'Hellessy',
#  'Helmstedt',
#  'Helmut_Lang',
#  'Helô_Rocha',
#  'Henrik_Vibskov',
#  'Hensely',
#  'Heohwan_Simulation',
#  'Hermès',
#  'Hernández_Cornet',
#  'Heron_Preston',
#  'Hervé_Léger',
#  'Hervé_Léger_by_Max_Azria',
#  'Hillier_Bartley',
#  'Hiraeth',
#  'Hodakova',
#  'Holiday_Boileau',
#  'Holiday_by_Emma_Mulholland',
#  'Holly_Fulton',
#  'Holmes___Yang',
#  'Holzweiler',
#  'Homme_Plissé_Issey_Miyake',
#  'Honor',
#  'Hood_By_Air',
#  'Hope',
#  'Hope_For_Flowers',
#  'Houghton',
#  'House_of_Aama',
#  'House_of_Dagmar',
#  'House_of_Holland',
#  'House_of_Jazz',
#  'Hugo',
#  'HUI',
#  'Huishan_Zhang',
#  'Hunkydory',
#  'Hunter_Original',
#  'Hutson',
#  'Hyke',
#  'H_M_Design_Award',
#  'H_M_Studio',
#  'H_M_x_Moschino',
#  'Icarius_de_Menezes',
#  'ICB',
#  'Iceberg',
#  'Ida_Klamborn',
#  'Ida_Sjöstedt',
#  'Ienki_Ienki',
#  'Imitation_of_Christ',
#  'Inbal_Dror',
#  'Ingorokva',
#  'Inshade',
#  'Institut_Français_de_la_Mode',
#  'In_Earnest',
#  'Iordanes_Spyridon_Gogos',
#  'Iris_van_Herpen',
#  'Iro',
#  'Isaac_Mizrahi',
#  'Isabell_de_Hillerin',
#  'Isabel_Marant',
#  'Isa_Arfen',
#  'Issa',
#  'Issever_Bahri',
#  'Issey_Miyake',
#  'Istvan_Francer',
#  'Ivanman',
#  'Ivan_Grundahl',
#  'Ivka',
#  'Izzue',
#  'I’M_Isola_Marras',
#  'J6',
#  'Jacquemus',
#  'Jaeger_London',
#  'Jahnkoy',
#  'Jain_Song',
#  'James_Coviello',
#  'James_Long',
#  'Janashia',
#  'Jardin_Exotique',
#  'Jarret',
#  'Jasmine_Di_Milo',
#  'Jasmin_Shokrian',
#  'Jasmin_Shokrian_Draft_No__17',
#  'Jason_Wu',
#  'Jason_Wu_Collection',
#  'Jasper_Conran',
#  'Jayson_Brunsdon',
#  'Jay_Ahr',
#  'JC_de_Castelbajac',
#  'Jealousy',
#  'Jean_Colonna',
#  'Jean_Gritsfeldt',
#  'Jean_Paul_Gaultier',
#  'Jean_Pierre_Braganza',
#  'Jeffrey_Chow',
#  'Jeffrey_Dodd',
#  'Jeffrey_Rüdes',
#  'Jenni_Kayne',
#  'Jenny_Fax',
#  'Jenny_Packham',
#  'Jens_Laugesen',
#  'Jen_Kao',
#  'Jeremy_Laing',
#  'Jeremy_Scott',
#  'Jill_Stuart',
#  'Jil_Sander',
#  'Jil_Sander_Navy',
#  'Ji_Oh',
#  'JNBY',
#  'JOEONE',
#  'Johanna_Ortiz',
#  'Johan_Ku',
#  'John_Alexander_Skelton',
#  'John_Bartlett',
#  'John_Elliott',
#  'John_Galliano',
#  'John_John_Lab',
#  'John_Lawrence_Sullivan',
#  'John_Richmond',
#  'John_Rocha',
#  'John_Varvatos',
#  'Joie',
#  'Jonathan_Cohen',
#  'Jonathan_Saunders',
#  'Jordan_Dalah',
#  'Joseph',
#  'Joseph_Abboud',
#  'Josh_Goot',
#  'Josie_Natori',
#  'Jovovich_Hawk',
#  'Joy_Cioci',
#  'Jsen_Wintle',
#  'Juan_Carlos_Obando',
#  'Juan_Vidal',
#  'Judy_Turner',
#  'Juicy_Couture',
#  'Julian_Louie',
#  'Julian_Zigerli',
#  'Julia_Nikolaeva',
#  'Julia_Seemann',
#  'Julien_David',
#  'Julien_Macdonald',
#  'Julie_de_Libran',
#  'Julius',
#  'Junya_Watanabe',
#  'Jun_Ashida',
#  'Jun_Okamoto',
#  'Just_Cavalli',
#  'Juun_J',
#  'JW_Anderson',
#  'J_Brand',
#  'J_Crew',
#  'J_Koo',
#  'J_Lindeberg',
#  'J__JS_Lee',
#  'J__Kim',
#  'J__Mendel',
#  'Kaal_E_Suktae',
#  'Kaelen',
#  'Kai_Kühne',
#  'Kamishima_Chinami',
#  'Kanye_West',
#  'Karen_Walker',
#  'Karla_Spetic',
#  'Karl_Lagerfeld',
#  'Karl_Lagerfeld_for_Riachuelo',
#  'Karolina_Zmarlak',
#  'Katama',
#  'Katayone_Adeli',
#  'Katerina_Kvit',
#  'Kate_Spade_New_York',
#  'Kate_Sylvester',
#  'Katie_Eary',
#  'Katie_Ermilio',
#  'Katie_Gallagher',
#  'Katy_Rodriguez',
#  'Kaufmanfranco',
#  'Kaviar_Gauche',
#  'Keanan_Duffty',
#  'Keita_Maruyama',
#  'Kelly_Wearstler',
#  'Kendall___Kylie',
#  'Kenneth_Cole_Collection',
#  'Kenneth_Cole_New_York',
#  'Kenneth_Ize',
#  'Kent___Curwen',
#  'Kenzo',
#  'Kenzo_La_Collection_Memento',
#  'Kes',
#  'Kevork_Kiledjian',
#  'Khaite',
#  'Khomenko___Zirochka',
#  'KidSuper',
#  'Kiko_Kostadinov',
#  'Kilgour',
#  'Kilian_Kerner',
#  'Kimberly_Ovitz',
#  'Kimora_Lee_Simmons',
#  'Kim_Jones',
#  'Kim_Seo_Ryong',
#  'Kim_Shui',
#  'Kinder_Aggugini',
#  'Kiok',
#  'Kith',
#  'Kiton',
#  'Kitx',
#  'Knwls',
#  'Koché',
#  'Koi_Suwannagate',
#  'Kolor',
#  'Kotohayokozawa',
#  'Kozaburo',
#  'Kris_Van_Assche',
#  'Krizia',
#  'Krizia_Top',
#  'Krystof_Strozyna',
#  'KseniaSeraya',
#  'Ksenia_Schnaider',
#  'KTZ',
#  'Kudos___Soduk',
#  'Kuzyomin',
#  'Kwaidan_Editions',
#  'Kye',
#  'K_Krizia',
#  'Labrum_London',
#  'Lacoste',
#  'Lado_Bokuchava',
#  'Lafayette_148',
#  'Lagerfeld_Gallery',
#  'Lake_Studio',
#  'Lako_Bukia',
#  'Lala_Berlin',
#  'Lalo',
#  'Landlord',
#  'Lanvin',
#  'LaPointe',
#  'LaQuan_Smith',
#  'Larisa_Lobanova',
#  'Latimmier',
#  'Laura_Garcia',
#  'Laura_Siegel',
#  'Lauren_Manoogian',
#  'Laurèl',
#  'Lawrence_Steele',
#  'Lazoschmidl',
#  'La_DoubleJ',
#  'La_Martina_Resized_by_AP',
#  'La_Perla',
#  'La_Vie_Rebecca_Taylor',
#  'Lee_Mathews',
#  'Lee_Roach',
#  'Lein',
#  'Lela_Rose',
#  'Lemaire',
#  'Lemlem',
#  'Lena_Hoschek',
#  'Lenny_Niemeyer',
#  'Leonard_Paris',
#  'Les_Benjamins',
#  'Les_Copains',
#  'Les_Hommes',
#  'Le_Kilt',
#  'LGN_Louis_Gabriel_Nouchi',
#  'Libertine',
#  'Lie_Sangbong',
#  'Lilly_Sarti',
#  'Limi_Feu',
#  'Linder',
#  'Lindsey_Thornburg',
#  'Lisa_Marie_Fernandez',
#  'Lisa_Perry',
#  'Litkovskaya',
#  'Live_The_Process',
#  'Lizzy_Disney',
#  'Loden_Dager',
#  'Loewe',
#  'Longchamp',
#  'Lorena_Antoniazzi',
#  'Lorod',
#  'Loro_Piana',
#  'Louise_Friedlaender',
#  'Louise_Goldin',
#  'Louise_Gray',
#  'Louis_Shengtao_Chen',
#  'Louis_Vuitton',
#  'Lou_Dallas_by_Raffaella',
#  'Lou_Dalton',
#  'LoveShackFancy',
#  'Low_Classic',
#  'LRS',
#  'Luar',
#  'Lucas_Nascimento',
#  'Luca_Luca',
#  'Lucien_Pellat_Finet',
#  'Lucio_Vanotti',
#  'Lucky_Chouette',
#  'Ludovic_de_Saint_Sernin',
#  'Luella',
#  'Luisa_Beccaria',
#  'Lukhanyo_Mdingi',
#  'Lulu___Co',
#  'Lumiér_Garson',
#  'Lutz_Huelle',
#  'Lutz___Patmos',
#  'Lu_u_Dan',
#  'Lyn_Devon',
#  'L_Agence',
#  'L_A_M_B_',
#  'L_Wren_Scott',
#  'L’Homme_Rouge',
#  'M1992',
#  'Mach_Mach',
#  'Madewell',
#  'Mads_Nørgaard',
#  'Maggie_Marilyn',
#  'Magliano',
#  'Maid_in_Love',
#  'Maisie_Wilen',
#  'Maison_Francesco_Scognamiglio',
#  'Maison_Kitsuné',
#  'Maison_Margiela',
#  'Maison_Mayle',
#  'Maison_Mihara_Yasuhiro',
#  'Maison_Rabih_Kayrouz',
#  'Maiyet',
#  'Maje',
#  'Maki_Oh',
#  'Malaikaraiss',
#  'Malamute',
#  'Malo',
#  'Mame_Kurogouchi',
#  'MAN',
#  'Mandy_Coon',
#  'Manish_Arora',
#  'Mansur_Gavriel',
#  'Mantis_Religiosa',
#  'Mara_Hoffman',
#  'Marcelo_Burlon_County_of_Milan',
#  'Marcel_Ostertag',
#  'Marchesa',
#  'Marchesa_Notte',
#  'Marchesa_Voyage',
#  'Marco_de_Vincenzo',
#  'Marco_Rambaldi',
#  'Marc_by_Marc_Jacobs',
#  'Marc_Jacobs',
#  'Marc_Jacobs_Men',
#  'Margaret_Howell',
#  'Marianna_Senchina',
#  'Maria_Grachvogel',
#  'Maria_McManus',
#  'Marina_Hoermanseder',
#  'Marina_Moscone',
#  'Marine_Serre',
#  'Marios_Schwab',
#  ...]

# %%
class Faces(object):
    
    def __init__(self, face_cascade, face_dir, output_dir,):
        self.face_cascade = face_cascade
        self.image_num = 1
        self.dir_num = 1
        self.face_dir = face_dir
        self.output_dir = output_dir
        self.image_name = 'Face'
        self.error = []
        
    def face_co_ordinates(self, gray):
        return self.face_cascade.detectMultiScale(gray, 1.2, 4)
#         return face_classifier.detectMultiScale(gray, 1.2, 4)
    
    def draw_rectangle(self, image, co_ordinate):
        x,y,w,h = co_ordinate
        cv2.rectangle(image, (x,y), (x+w, y+h), (0,255,0), 2)
        return None
    
    def crop_face(self, image, co_ordinate):
        x,y,w,h = co_ordinate
        return image[y:y+h, x:x+w]
    
    def all_faces(self, draw_face=False):
        images = os.listdir(self.face_dir)
        print(self.dir_num, self.face_dir,'  starts with: ', self.image_num,'  having images:', len(images))
        for image_name in images:
            if image_name[-4:] == '.jpg':
                image = cv2.imread(os.path.join(self.face_dir, image_name))
                gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
                co_ordinates = self.face_co_ordinates(gray)

                if len(co_ordinates) > 0:
                    for co_ordinate in co_ordinates:
                        if draw_face:
                            self.draw_rectangle(image, co_ordinate)
                            cv2.imshow('Sunny', image)
                            cv2.waitKey(500)
                        else:
                            try:
                                crop_image = self.crop_face(image, co_ordinate)
                                name = os.path.join(self.output_dir, self.image_name + str(self.image_num) +'.jpg')
                                cv2.imwrite(name, crop_image)
                                self.image_num += 1
                            except:
                                self.error.append(image_name)
                                continue
        print('No. of errors: ', len(self.error))
        print('====================================================================================================')
        data = {'Errors': self.error}
        df = pd.DataFrame(data)
        img_dir = self.face_dir.replace('./IMAGES/', '')
        err_file = os.path.join(self.output_dir, 'error_'+img_dir[:-1]+'.csv')
        df.to_csv(err_file)
        cv2.destroyAllWindows()
        return None

# %%
classifier_path = r'F:\Documents\PROJECT\Face\HAARCASCADE'
classifier = os.listdir(classifier_path)
face_classifier = cv2.CascadeClassifier(os.path.join(classifier_path, classifier[0]))

# %%
class Faces(object):
    
    def __init__(self, face_cascade, face_dir, output_dir,):
        self.face_cascade = face_cascade
        self.image_num = 1
        self.dir_num = 1
        self.face_dir = face_dir
        self.output_dir = output_dir
        self.image_name = 'Face'
        self.error = []
        
    def face_co_ordinates(self, gray):
        return self.face_cascade.detectMultiScale(gray, 1.2, 4)
#         return face_classifier.detectMultiScale(gray, 1.2, 4)

    def neck_cordinates(self, x,y,w,h):
        return int(x+(w/8)), (y+h), int(w-(w/4)), int(h*0.4)
    
    def upper_half_torso_cordinates(self, x,y,w,h, h1):
        return int(x - (w/2)), (y+h+h1), 2*w, 2*h
        
    def lower_half_torso_cordinates(self, x,y,w,h, h_):
        return x, y+h, w, h_
    
    def legs_cordinates(self, x,y,w,h, h_):
        return x, y+h, w, 4*h_
    
    def foot_cordinates(self, x,y,w,h, h_):
        return x, y+h, w, int(h_/2)
    
    def colors(self):
        return (random.choice(range(0, 255)), random.choice(range(0, 255)), random.choice(range(0, 255)))
    
    def draw_rectangle(self, image, co_ordinate, color):
        x,y,w,h = co_ordinate
        cv2.rectangle(image, (x,y), (x+w, y+h), color, 2)
        return None
    
    def crop_face(self, image, co_ordinate):
        x,y,w,h = co_ordinate
        return image[y:y+h, x:x+w]
    
    def all_faces(self, draw_face=False):
        if self.face_dir:
            images = os.listdir(self.face_dir)
            print(self.dir_num, self.face_dir,'  starts with: ', self.image_num,'  having images:', len(images))
            for image_name in images:
                if image_name[-4:] == '.jpg':
                    image = cv2.imread(os.path.join(self.face_dir, image_name))
                    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
                    co_ordinates = self.face_co_ordinates(gray)

                    if len(co_ordinates) > 0:
                        for co_ordinate in co_ordinates:
                            if draw_face:
                                x,y,w,h = co_ordinate
                                self.draw_rectangle(image, co_ordinate)
                                x1, y1, w1, h1 = self.neck_cordinates(x,y,w,h)
                                self.draw_rectangle(image, (x1, y1, w1, h1))
                                x2, y2, w2, h2 = self.upper_half_torso_cordinates(x,y,w,h,h1)
                                self.draw_rectangle(image, (x2, y2, w2, h2))
                                x3, y3, w3, h3 = self.lower_half_torso_cordinates(x3, y3, w3, h3, h)
                                self.draw_rectangle(image, (x3, y3, w3, h3))
                                x4, y4, w4, h4 = self.legs_cordinates(x3, y3, w3, h3, h_)
                                self.draw_rectangle(image, (x4, y4, w4, h4))
                                x5, y5, w5, h5 = self.foot_cordinates(x4, y4, w4, h4, h_)
                                self.draw_rectangle(image, (x5, y5, w5, h5))
                                cv2.imshow('Sunny', image)
                                cv2.waitKey(500)
                            else:
                                break
#                             try:
#                                 crop_image = self.crop_face(image, co_ordinate)
#                                 name = os.path.join(self.output_dir, self.image_name + str(self.image_num) +'.jpg')
#                                 cv2.imwrite(name, crop_image)
#                                 self.image_num += 1
#                             except:
#                                 self.error.append(image_name)
#                                 continue
            print('No. of errors: ', len(self.error))
            print('====================================================================================================')
            data = {'Errors': self.error}
            df = pd.DataFrame(data)
            img_dir = self.face_dir.replace('./IMAGES/', '')
            err_file = os.path.join(self.output_dir, 'error_'+img_dir[:-1]+'.csv')
            df.to_csv(err_file)
            cv2.destroyAllWindows()
        return None

# %%
class NodeCNN(nn.Module):
    
    def __init__(self):
        
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=1,out_channels=4, kernel_size=3,stride=1,padding=1,dilation=1,groups=1,bias=True,)
        self.conv2 = nn.Conv2d(in_channels=4,out_channels=16, kernel_size=3,stride=1,padding=1,dilation=1,groups=1,bias=True,)
        # self.conv2 = nn.Conv2d(in_channels=8,out_channels=16, kernel_size=3,stride=1,padding=1,dilation=1,groups=1,bias=True,)
        
        self.fc1 = nn.Linear(2*2*16*16, 128)
        self.fc2 = nn.Linear(128, 16)
        self.fc3 = nn.Linear(16, 2)
        
    def forward(self, X):
        
        X = F.relu(self.conv1(X))
        X = F.max_pool2d(X, 2,2)
        X = F.relu(self.conv2(X))
        X = F.max_pool2d(X, 2,2)
        # X = F.relu(self.conv3(X))
        # X = F.max_pool2d(X, 2,2)
        X = X.view(-1, 16*16*2*2)
        X = F.relu(self.fc1(X))
        X = F.relu(self.fc2(X))
        X = self.fc3(X)
        
        return F.log_softmax(X, dim=1)

# %%
model = NodeCNN()

# %%
model_path = r'F:\Documents\PROJECT\Face\FACE_CLASSIFIER_MODEL_2'

test_model_path = os.path.join(model_path, "FRS_CLASSIFIER_Model_50.net")
model.load_state_dict(torch.load(test_model_path, map_location=torch.device('cpu')))
# Out:
# <All keys matched successfully>

# %%
model.eval()
# Out:
# NodeCNN(
#   (conv1): Conv2d(1, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(4, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fc1): Linear(in_features=1024, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=16, bias=True)
#   (fc3): Linear(in_features=16, out_features=2, bias=True)
# )

# %%
class CroquieDetection(Faces):

    def __init__(self, face_cascade, face_dir=None, output_dir=None):
        Faces.__init__(self, face_cascade, face_dir, output_dir)
        if output_dir:
            if not os.path.exists(output_dir):
                os.makedirs(output_dir)
        self.video_num = 1
        self.is_face = False
    
    @staticmethod
    def resize_with_aspect_ratio(img, width=640, inter=cv2.INTER_AREA):
        h,w = img.shape[:2]
        r = width/float(w)
        dim = width, int(h*r)
        return cv2.resize(img, dim, interpolation=inter)
        
    def parts_detect(self, img_path, draw_face=False):
        image = cv2.imread(img_path, cv2.IMREAD_COLOR)
#         print('SHAPE -->', image.shape)
        try:
            image = np.uint8(image)
            gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        except:
#             print(traceback.print_exc())
            return None
        co_ordinates = self.face_co_ordinates(gray)
#         print('CO-ORDINATES: -->', co_ordinates)
        if len(co_ordinates) > 0:
            for co_ordinate in co_ordinates:
                self.is_face=False
                if draw_face:
                    color = self.colors()
                    x,y,w,h = co_ordinate
                    try:
                        crop_image = self.crop_face(image, co_ordinate)
#                         name = os.path.join(self.output_dir, self.image_name + str(self.image_num) +'.jpg')
#                         cv2.imwrite(name, crop_image)
                        self.image_num += 1
                    except:
                        print("Crop Face Error", traceback.print_exc())
                    try:
                        x_ = cv2.resize(cv2.cvtColor(crop_image, cv2.COLOR_BGR2GRAY), (2*16, 32))/255
                        x_ = x_.astype(np.float32)
                        x_ = torch.tensor(x_)
                        x_ = x_.view((1,1,32,16*2))
                        pred = model(x_)

                        pred = int(pred.argmax().item())

                        if pred == 1:
#                             print("true face detected ----------- ")
                            self.is_face = True

                    except:
                        print("Node CNN Error: ", traceback.print_exc())

                    if self.is_face:
                        self.draw_rectangle(image, co_ordinate, color)
                        x1, y1, w1, h1 = self.neck_cordinates(x,y,w,h)
                        self.draw_rectangle(image, (x1, y1, w1, h1), color)
                        x2, y2, w2, h2 = self.upper_half_torso_cordinates(x,y,w,h,h1)
                        self.draw_rectangle(image, (x2, y2, w2, h2), color)
#                         print("888888888888888888888888")
                        x3, y3, w3, h3 = self.lower_half_torso_cordinates(x2, y2, w2, h2, h)
                        self.draw_rectangle(image, (x3, y3, w3, h3), color)
                        x4, y4, w4, h4 = self.legs_cordinates(x3, y3, w3, h3, h)
                        self.draw_rectangle(image, (x4, y4, w4, h4), color)
#                         print("999999999999999999999999")
                        x5, y5, w5, h5 = self.foot_cordinates(x4, y4, w4, h4, h)
                        self.draw_rectangle(image, (x5, y5, w5, h5), color)
#                             self.image_num += 1
        image = self.resize_with_aspect_ratio(img=image)
#         cv2.imshow('Fashion Show', image)
#         cv2.waitKey(-1)
        return image

# %%
def croq_detection_on_dataset(output_dir="./Output"):
#     brand = random.choice(os.listdir(Vogue_path))
#     brand_path = os.path.join(Vogue_path, brand)
#     collection = random.choice(os.listdir(brand_path))
#     collection_path = os.path.join(brand_path, collection)
#     image_path = os.path.join(collection_path, random.choice(os.listdir(collection_path)))
    brands = os.listdir(Vogue_path)
    for brand in tqdm(brands, desc='Brands -- '):
        brand_path = os.path.join(Vogue_path, brand)
        collections = os.listdir(brand_path)
        for collection in collections:
            collection_path = os.path.join(brand_path, collection)
            image_names = os.listdir(collection_path)
            op_path = os.path.join(output_dir, f"{brand}\\{collection}")
            if not os.path.exists(op_path):
                os.makedirs(op_path)
            for image_name in image_names:
                image_path = os.path.join(collection_path, image_name)
                try:
                    crd = CroquieDetection(face_cascade=face_classifier)
                    op_image = crd.parts_detect(img_path=image_path, draw_face=True)
                    cv2.imwrite(os.path.join(op_path, image_name), op_image)
                except:
                    print("Croq Detection Module Error:", traceback.print_exc())
                    continue

# %%
croq_detection_on_dataset()
# Out:
# Brands -- :   0%|▏                                                                | 4/1750 [08:42<63:42:18, 131.35s/it]Traceback (most recent call last):
#   File "<ipython-input-13-1414ee60195c>", line 22, in croq_detection_on_dataset
#     cv2.imwrite(os.path.join(op_path, image_name), op_image)
# cv2.error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:801: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
# Croq Detection Module Error: None
# Brands -- :   0%|▎                                                             | 8/1750 [2:09:09<430:27:24, 889.58s/it]

# %%
cv2.imread(image_path)

# %%
# ! pip install matplotlib
# ! pip uninstall jedi -y
# ! pip freeze

# %%
# https://www.pinterest.com/pin/778700591793046882/

# %%
class Faces(object):
    
    def __init__(self, face_cascade, face_dir, output_dir,):
        self.face_cascade = face_cascade
        self.image_num = 1
        self.dir_num = 1
        self.face_dir = face_dir
        self.output_dir = output_dir
        self.image_name = 'Face'
        self.error = []
        
    def face_co_ordinates(self, gray):
        return self.face_cascade.detectMultiScale(gray, 1.2, 4)
#         return face_classifier.detectMultiScale(gray, 1.2, 4)
    
    def draw_rectangle(self, image, co_ordinate):
        x,y,w,h = co_ordinate
        cv2.rectangle(image, (x,y), (x+w, y+h), (0,255,0), 2)
        return None
    
    def crop_face(self, image, co_ordinate):
        x,y,w,h = co_ordinate
        return image[y:y+h, x:x+w]
    
    def all_faces(self, draw_face=False):
        images = os.listdir(self.face_dir)
        print(self.dir_num, self.face_dir,'  starts with: ', self.image_num,'  having images:', len(images))
        for image_name in images:
            if image_name[-4:] == '.jpg':
                image = cv2.imread(os.path.join(self.face_dir, image_name))
                gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
                co_ordinates = self.face_co_ordinates(gray)

                if len(co_ordinates) > 0:
                    for co_ordinate in co_ordinates:
                        if draw_face:
                            self.draw_rectangle(image, co_ordinate)
                            cv2.imshow('Sunny', image)
                            cv2.waitKey(500)
                        else:
                            try:
                                crop_image = self.crop_face(image, co_ordinate)
                                name = os.path.join(self.output_dir, self.image_name + str(self.image_num) +'.jpg')
                                cv2.imwrite(name, crop_image)
                                self.image_num += 1
                            except:
                                self.error.append(image_name)
                                continue
        print('No. of errors: ', len(self.error))
        print('====================================================================================================')
        data = {'Errors': self.error}
        df = pd.DataFrame(data)
        img_dir = self.face_dir.replace('./IMAGES/', '')
        err_file = os.path.join(self.output_dir, 'error_'+img_dir[:-1]+'.csv')
        df.to_csv(err_file)
        cv2.destroyAllWindows()
        return None

# %%
classifier_path = '../HAARCASCADE/'
classifier = os.listdir(classifier_path)
face_classifier = cv2.CascadeClassifier(os.path.join(classifier_path, classifier[0]))

# %%
img_path = "/home/innefu/Documents/PROJECT/INNEFU/MY_BUILD/Face/Fashion_dummy"
imgs = os.listdir(img_path)
imgs

# %%
# img = cv2.cvtColor(cv2.imread(os.path.join(img_path, imgs[0]), cv2.IMREAD_COLOR), cv2.COLOR_BGR2RGB)
img = cv2.imread(os.path.join(img_path, imgs[0]), cv2.IMREAD_COLOR)
gray = cv2.imread(os.path.join(img_path, imgs[0]), cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(gray, cmap='gray')

# %%
faces_arr = face_classifier.detectMultiScale(gray, 1.2, 4)
faces_arr

# %%
plt.figure(figsize=(12,12))
for i in faces_arr:
    x,y,w,h = i
    plt.imshow(cv2.rectangle(img, (x,y), (x+w, y+h), (0,255,0), 2))

# %%
x,y,w,h = i
neck = np.array([int(x+(w/8)), (y+h), int(w-(w/4)), int(h*0.4)])
x1, y1, w1, h1 = neck

# %%
plt.figure(figsize=(12,12))
plt.imshow(cv2.rectangle(img, (x,y), (x+w, y+h), (0,255,0), 2))
plt.imshow(cv2.rectangle(img, (x1,y1), (x1+w1, y1+h1), (0,255,0), 2))

# %%
x2, y2, w2, h2 = np.array([int(x - (w/2)), (y+h+h1), 2*w, 2*h])
x2, y2, w2, h2

# %%
plt.figure(figsize=(12,12))
plt.imshow(cv2.rectangle(img, (x2,y2), (x2+w2, y2+h2), (0,255,0), 2))

# %%
x3, y3, w3, h3 = np.array([x2, y2+h2, w2, h])
x3, y3, w3, h3

# %%
plt.figure(figsize=(12,12))
plt.imshow(cv2.rectangle(img, (x3,y3), (x3+w3, y3+h3), (0,255,0), 2))

# %%
x4, y4, w4, h4 = np.array([x3, y3+h3, w3, 4*h])
x4, y4, w4, h4

# %%
plt.figure(figsize=(12,12))
plt.imshow(cv2.rectangle(img, (x4,y4), (x4+w4, y4+h4), (0,255,0), 2))

# %%
x5, y5, w5, h5 = np.array([x4, y4+h4, w4, int(h/2)])
x5, y5, w5, h5

# %%
plt.figure(figsize=(12,12))
plt.imshow(cv2.rectangle(img, (x5,y5), (x5+w5, y5+h5), (0,255,0), 2))

# %%
class Faces(object):
    
    def __init__(self, face_cascade, face_dir, output_dir,):
        self.face_cascade = face_cascade
        self.image_num = 1
        self.dir_num = 1
        self.face_dir = face_dir
        self.output_dir = output_dir
        self.image_name = 'Face'
        self.error = []
        
    def face_co_ordinates(self, gray):
        return self.face_cascade.detectMultiScale(gray, 1.2, 4)
#         return face_classifier.detectMultiScale(gray, 1.2, 4)
    
    def draw_rectangle(self, image, co_ordinate):
        x,y,w,h = co_ordinate
        cv2.rectangle(image, (x,y), (x+w, y+h), (0,255,0), 2)
        return None
    
    def crop_face(self, image, co_ordinate):
        x,y,w,h = co_ordinate
        return image[y:y+h, x:x+w]
    
    def all_faces(self, draw_face=False):
        images = os.listdir(self.face_dir)
        print(self.dir_num, self.face_dir,'  starts with: ', self.image_num,'  having images:', len(images))
        for image_name in images:
            if image_name[-4:] == '.jpg':
                image = cv2.imread(os.path.join(self.face_dir, image_name))
                gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
                co_ordinates = self.face_co_ordinates(gray)

                if len(co_ordinates) > 0:
                    for co_ordinate in co_ordinates:
                        if draw_face:
                            self.draw_rectangle(image, co_ordinate)
                            cv2.imshow('Sunny', image)
                            cv2.waitKey(500)
                        else:
                            try:
                                crop_image = self.crop_face(image, co_ordinate)
                                name = os.path.join(self.output_dir, self.image_name + str(self.image_num) +'.jpg')
                                cv2.imwrite(name, crop_image)
                                self.image_num += 1
                            except:
                                self.error.append(image_name)
                                continue
        print('No. of errors: ', len(self.error))
        print('====================================================================================================')
        data = {'Errors': self.error}
        df = pd.DataFrame(data)
        img_dir = self.face_dir.replace('./IMAGES/', '')
        err_file = os.path.join(self.output_dir, 'error_'+img_dir[:-1]+'.csv')
        df.to_csv(err_file)
        cv2.destroyAllWindows()
        return None

# %%
class VideoFace(Faces):
    
    def __init__(self, video_path, face_cascade, face_dir, output_dir):
        Faces.__init__(self, face_cascade, face_dir, output_dir)
        self.video = video_path
        self.video_num = 1
        
    def get_video_face(self, draw_face=False):
        
        cap = cv2.VideoCapture(self.video)
        print(self.video_num, 'Video Running -->', self.video)
        while True:
            success, image = cap.read()
            try:
                image = np.uint8(image)
                gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
            except:
                break
                
            co_ordinates = self.face_co_ordinates(gray)

            if len(co_ordinates) > 0:
                for co_ordinate in co_ordinates:
                    if draw_face:
                        self.draw_rectangle(image, co_ordinate)
                        cv2.imshow('Sunny', image)
                        cv2.waitKey(1)
                    else:
                        try:
                            crop_image = self.crop_face(image, co_ordinate)
                            name = os.path.join(self.output_dir, self.image_name + str(self.image_num) +'.jpg')
                            cv2.imwrite(name, crop_image)
                            self.image_num += 1
                        except:
                            self.error.append(image_name)
                            continue

        cap.release()
        cv2.destroyAllWindows()
        return None

# %%
def get_all_video_faces():
    classifier_path = './HAARCASCADE/'
    classifier = os.listdir(classifier_path)
    face_classifier = cv2.CascadeClassifier(os.path.join(classifier_path, classifier[0]))
    
    images_dir_path = './IMAGES/'
    output_dir = './FACES2/'
    video_dir_path = './MY/VIDEO/'
    image_num = 50000
    dir_num = 1
    vid_num = 1
    images_path = './None'
    
    video_dir = os.listdir(video_dir_path)
    
    for video in video_dir:
        video_path = os.path.join(video_dir_path, video)
        vf = VideoFace(video_path, face_classifier, images_path, output_dir)
        vf.image_num = image_num
        vf.vid_num = vid_num
        vf.get_video_face(draw_face=False)
        
        image_num = vf.image_num
        vid_num += 1
    cv2.destroyAllWindows()
    return None

# %%
# get_all_video_faces()

# %%
path = './'
os.listdir(path)

# %%
def get_all_faces():
    classifier_path = './HAARCASCADE/'
    classifier = os.listdir(classifier_path)
    face_classifier = cv2.CascadeClassifier(os.path.join(classifier_path, classifier[0]))
    
    images_dir_path = './MY/'
    output_dir = './FACES2/'
    image_num = 50000
    dir_num = 1
    
    images_dirs = os.listdir(images_dir_path)
    
    for image_dir in images_dirs:
        images_path = os.path.join(images_dir_path, image_dir)
        fc = Faces(face_classifier, images_path, output_dir)
        fc.image_num = image_num
        fc.dir_num = dir_num
        fc.all_faces()
        image_num = fc.image_num
        dir_num += 1

# %%
# get_all_faces()

# %%
final_face_path = './FINAL-FACES/'

# %%
final_face_images = os.listdir(final_face_path)

# %%
imgs_name  = []
imgs_shape = []
for i in final_face_images:
    img = cv2.imread(os.path.join(final_face_path, i))
    imgs_name.append(i)
    imgs_shape.append(img.shape[0])

# %%
plt.plot(np.arange(len(imgs_shape)), sorted(imgs_shape))

# %%
data = {
    'image': imgs_name,
    'shape': imgs_shape,
}

df = pd.DataFrame(data)

# %%
x = np.array(imgs_shape)

# %%
x[x>1000]

# %%
df[df['shape']>1000]

# %%
sunny_img = cv2.imread(os.path.join(sunny_images_path, 'Image99.jpg'))

# %%
for i in sunny_images[51:200]:
    sunny_img = cv2.imread(os.path.join(sunny_images_path, i))
    
    gray = cv2.cvtColor(sunny_img, cv2.COLOR_BGR2GRAY)
    
    faces = face_classifier.detectMultiScale(gray, 1.1, 4)
    
    for (x,y,w,h) in faces:
        cv2.rectangle(sunny_img, (x,y), (x+w, y+h), (0, 255,0), 3)
    cv2.imshow('sunny', sunny_img)
    cv2.waitKey(1500)
cv2.destroyAllWindows()

# %%
sunny_img.shape

# %%
x,y,w,h

# %%
raw = sunny_img[y:y+h, x:x+w]

# %%
plt.imshow(raw)

# %%
plt.imshow(sunny_img)

# %%
p = 'k/l/m/'

# %%
os.path.basename(p)

# %%
plt.imshow(sunny_img)

# %%
gray = cv2.cvtColor(sunny_img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)
# gray = cv2.flip(gray, 1)

# %%
faces = face_classifier.detectMultiScale(gray, 1.1, 4)

# %%
faces

# %%
img = sunny_img.copy()
# img = cv2.flip(img, 1)
plt.imshow(img)

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(img, (x,y), (x+w, y+h), (0, 255,0), 3)

# %%
plt.imshow(img)

# %%
raw = img[y:y+h, x:x+w]

# %%
plt.imshow(raw)
